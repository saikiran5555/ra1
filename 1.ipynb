# %% [markdown]
# Simple Linear Regression and Multiple Linear Regression are both statistical methods used to model the relationship between independent variable(s) and a dependent variable. The key difference lies in the number of independent variables they consider.
#
# Simple Linear Regression:
# Definition: Simple Linear Regression is a statistical method that models the relationship between a single independent variable (predictor) and a dependent variable (outcome) by fitting a linear equation to observed data. The equation of a simple linear regression line is:
# �
# =
# �
# 0
# +
# �
# 1
# �
# +
# �
# y=β
# 0
# ​
#  +β
# 1
# ​
#  x+ϵ
# where
# �
# y is the dependent variable,
# �
# x is the independent variable,
# �
# 0
# β
# 0
# ​
#   is the y-intercept,
# �
# 1
# β
# 1
# ​
#   is the slope of the line, and
# �
# ϵ is the error term.
#
# Assumptions: It assumes a linear relationship between the two variables, homoscedasticity (constant variance of errors), independence of errors, and normally distributed errors.
#
# Example: Consider a study examining the relationship between hours of study (independent variable) and test scores (dependent variable). Here, you would use simple linear regression to predict test scores based on the number of hours spent studying.
#
# Multiple Linear Regression:
# Definition: Multiple Linear Regression extends simple linear regression by modeling the relationship between two or more independent variables and a dependent variable. The equation of a multiple linear regression is:
# �
# =
# �
# 0
# +
# �
# 1
# �
# 1
# +
# �
# 2
# �
# 2
# +
# .
# .
# .
# +
# �
# �
# �
# �
# +
# �
# y=β
# 0
# ​
#  +β
# 1
# ​
#  x
# 1
# ​
#  +β
# 2
# ​
#  x
# 2
# ​
#  +...+β
# n
# ​
#  x
# n
# ​
#  +ϵ
# where
# �
# y is the dependent variable,
# �
# 1
# ,
# �
# 2
# ,
# .
# .
# .
# ,
# �
# �
# x
# 1
# ​
#  ,x
# 2
# ​
#  ,...,x
# n
# ​
#   are the independent variables,
# �
# 0
# β
# 0
# ​
#   is the y-intercept,
# �
# 1
# ,
# �
# 2
# ,
# .
# .
# .
# ,
# �
# �
# β
# 1
# ​
#  ,β
# 2
# ​
#  ,...,β
# n
# ​
#   are the coefficients of the independent variables, and
# �
# ϵ is the error term.
#
# Assumptions: It includes all assumptions of simple linear regression and additionally assumes no multicollinearity (independent variables are not highly correlated with each other).
#
# Example: Suppose you want to predict house prices (dependent variable) based on multiple factors such as size (sq ft), number of bedrooms, age of the house, and location. Multiple linear regression would allow you to include all these variables in your model to predict the price of a house.
